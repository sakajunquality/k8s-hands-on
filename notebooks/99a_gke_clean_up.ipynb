# %% [markdown]
# # 99. GKE Clean UP

# %%
export PROJECT_ID=k8s-hands-on-quality
export CLUSTER_NAME=k8s-hands-on
export CLUSTER_ZONE=us-west1-c

# %% [markdown]
# ## 99.1 Destroy the GKE Cluster

# %%
gcloud container clusters list
# Out:
# NAME          LOCATION    MASTER_VERSION  MASTER_IP       MACHINE_TYPE   NODE_VERSION  NUM_NODES  STATUS
# k8s-hands-on  us-west1-c  1.10.7-gke.1    35.199.190.247  n1-standard-1  1.10.7-gke.1  3          RUNNING

# %%
gcloud container clusters delete $CLUSTER_NAME --zone $CLUSTER_ZONE --project $PROJECT_ID -q
# Out:
# Deleting cluster k8s-hands-on...done.
# Deleted [https://container.googleapis.com/v1/projects/k8s-hands-on-quality/zones/us-west1-c/clusters/k8s-hands-on].
